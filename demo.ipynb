# %%
## we have to copy this code from mongo db atlas and then have to paste it here,,
#write your own  password in password area provided in uri 
from pymongo import MongoClient

uri = "mongodb+srv://datascience:<password>@cluster0.iar118v.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
## create a database
mydb=client["mydatabase"]

# %%
##create collection
mycol=mydb["myfirstcollection"]  #name of your collection

# %%
#enter record 
myfirstrecord={"name":"rahul","lname":"sharma","city":"kolkata"}

# %%
myfirstrecord
# Out:
# {'name': 'rahul', 'lname': 'sharma', 'city': 'kolkata'}

# %%
##to insert record in collection
mycol.insert_one(myfirstrecord)
# Out:
# InsertOneResult(ObjectId('663a62b2e179d4b4b06bfea0'), acknowledged=True)

# %%
##inserting second record
mysecondrecord={"name":"mannat","lname":"kaur","city":"kerala"}

# %%
mycol.insert_one(mysecondrecord) #inserting record to collection
# Out:
# InsertOneResult(ObjectId('663a62b6e179d4b4b06bfea1'), acknowledged=True)

# %%
records={"name":"ritvik","lname":"arora","city":"mumbai","salary":130000}

# %%
mycol.insert_one(records)
# Out:
# InsertOneResult(ObjectId('663a62bae179d4b4b06bfea2'), acknowledged=True)

# %%
client.list_database_names()
# Out:
# ['mydatabase', 'sample_mflix', 'admin', 'local']

# %%
multiplerecord=[
    
    {"name":"swati","lname":"kakkar","city":"ludhiana","salary":65000},
    {"name":"divyansh","lname":"chugh","city":"rohtak","salary":34000},
    {"name":"abhi","lname":"jain","city":"panipat","salary":140000},
    {"name":"kartik","lname":"saluja","city":"mumbai","salary":34000}
    ]

# %%
leftrecord=[
    {"name":"kanika","lname":"kapoor","city":"jaipur","salary":89000},
    {"name":"jeeya","lname":"mehra","city":"ludhiana","salary":34000},
    {"name":"angel","lname":"chugh","city":"udaipur","salary":45000},
    ]

# %%
x=mycol.insert_many(leftrecord)

# %%
x.inserted_ids
# Out:
# [ObjectId('663a66d8e179d4b4b06bfea8'),
#  ObjectId('663a66d8e179d4b4b06bfea9'),
#  ObjectId('663a66d8e179d4b4b06bfeaa')]

# %%
# to fetch single record
mycol.find_one()
# Out:
# {'_id': ObjectId('663a176a895867b3c2a1a645'),
#  'name': 'rahul',
#  'lname': 'sharma',
#  'city': 'kolkata'}

# %%
## to fetch multiple records
for x in mycol.find():
    print(x)
# Out:
# {'_id': ObjectId('663a176a895867b3c2a1a645'), 'name': 'rahul', 'lname': 'sharma', 'city': 'kolkata'}
# {'_id': ObjectId('663a1835895867b3c2a1a646'), 'name': 'mannat', 'lname': 'kaur', 'city': 'kerala'}
# {'_id': ObjectId('663a194f895867b3c2a1a647'), 'name': 'ritvik', 'lname': 'arora', 'city': 'mumbai', 'salary': 130000}
# {'_id': ObjectId('663a62b2e179d4b4b06bfea0'), 'name': 'rahul', 'lname': 'sharma', 'city': 'kolkata'}
# {'_id': ObjectId('663a62b6e179d4b4b06bfea1'), 'name': 'mannat', 'lname': 'kaur', 'city': 'kerala'}
# {'_id': ObjectId('663a62bae179d4b4b06bfea2'), 'name': 'ritvik', 'lname': 'arora', 'city': 'mumbai', 'salary': 130000}
# {'_id': ObjectId('663a6579e179d4b4b06bfea3'), 'name': 'manpreet', 'lname': 'arora', 'city': 'jal', 'salary': 20000}
# {'_id': ObjectId('663a6579e179d4b4b06bfea4'), 'name': 'swati', 'lname': 'kakkar', 'city': 'ludhiana', 'salary': 65000}
# ...

# %%
#fetch record based on a condition
mycol.find_one({"lname":"mehra"})
# Out:
# {'_id': ObjectId('663a66d8e179d4b4b06bfea9'),
#  'name': 'jeeya',
#  'lname': 'mehra',
#  'city': 'ludhiana',
#  'salary': 34000}

# %%
for x in mycol.find({"city":"ludhiana"}):
    print(x)
# Out:
# {'_id': ObjectId('663a6579e179d4b4b06bfea4'), 'name': 'swati', 'lname': 'kakkar', 'city': 'ludhiana', 'salary': 65000}
# {'_id': ObjectId('663a66d8e179d4b4b06bfea9'), 'name': 'jeeya', 'lname': 'mehra', 'city': 'ludhiana', 'salary': 34000}

# %%
# sorting
for x in mycol.find().sort("name"):
    print(x)
# Out:
# {'_id': ObjectId('663a6579e179d4b4b06bfea6'), 'name': 'abhi', 'lname': 'jain', 'city': 'panipat', 'salary': 140000}
# {'_id': ObjectId('663a66d8e179d4b4b06bfeaa'), 'name': 'angel', 'lname': 'chugh', 'city': 'udaipur', 'salary': 45000}
# {'_id': ObjectId('663a6579e179d4b4b06bfea5'), 'name': 'divyansh', 'lname': 'chugh', 'city': 'rohtak', 'salary': 34000}
# {'_id': ObjectId('663a66d8e179d4b4b06bfea9'), 'name': 'jeeya', 'lname': 'mehra', 'city': 'ludhiana', 'salary': 34000}
# {'_id': ObjectId('663a66d8e179d4b4b06bfea8'), 'name': 'kanika', 'lname': 'kapoor', 'city': 'jaipur', 'salary': 89000}
# {'_id': ObjectId('663a6579e179d4b4b06bfea7'), 'name': 'kartik', 'lname': 'saluja', 'city': 'mumbai', 'salary': 34000}
# {'_id': ObjectId('663a1835895867b3c2a1a646'), 'name': 'mannat', 'lname': 'kaur', 'city': 'kerala'}
# {'_id': ObjectId('663a62b6e179d4b4b06bfea1'), 'name': 'mannat', 'lname': 'kaur', 'city': 'kerala'}
# ...

# %%
# to sort record in descending order
for x in mycol.find().sort("name",-1):
    print(x)
# Out:
# {'_id': ObjectId('663a6579e179d4b4b06bfea4'), 'name': 'swati', 'lname': 'kakkar', 'city': 'ludhiana', 'salary': 65000}
# {'_id': ObjectId('663a194f895867b3c2a1a647'), 'name': 'ritvik', 'lname': 'arora', 'city': 'mumbai', 'salary': 130000}
# {'_id': ObjectId('663a62bae179d4b4b06bfea2'), 'name': 'ritvik', 'lname': 'arora', 'city': 'mumbai', 'salary': 130000}
# {'_id': ObjectId('663a176a895867b3c2a1a645'), 'name': 'rahul', 'lname': 'sharma', 'city': 'kolkata'}
# {'_id': ObjectId('663a62b2e179d4b4b06bfea0'), 'name': 'rahul', 'lname': 'sharma', 'city': 'kolkata'}
# {'_id': ObjectId('663a6579e179d4b4b06bfea3'), 'name': 'manpreet', 'lname': 'arora', 'city': 'jal', 'salary': 20000}
# {'_id': ObjectId('663a1835895867b3c2a1a646'), 'name': 'mannat', 'lname': 'kaur', 'city': 'kerala'}
# {'_id': ObjectId('663a62b6e179d4b4b06bfea1'), 'name': 'mannat', 'lname': 'kaur', 'city': 'kerala'}
# ...

# %%
# to delete record
mycol.delete_one({"name":"angel"})
# Out:
# DeleteResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000002f9'), 'opTime': {'ts': Timestamp(1715104950, 14), 't': 761}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1715104950, 14), 'signature': {'hash': b'F\x98\xc2$\xa6\xf2\x1b\x03O)]\xd1\x01\x07o\x1d\xf3\x9b\x8ej', 'keyId': 7326027773800087553}}, 'operationTime': Timestamp(1715104950, 14)}, acknowledged=True)

# %%
for x in mycol.find().sort("name"):
    print(x)
# Out:
# {'_id': ObjectId('663a6579e179d4b4b06bfea6'), 'name': 'abhi', 'lname': 'jain', 'city': 'panipat', 'salary': 140000}
# {'_id': ObjectId('663a6579e179d4b4b06bfea5'), 'name': 'divyansh', 'lname': 'chugh', 'city': 'rohtak', 'salary': 34000}
# {'_id': ObjectId('663a66d8e179d4b4b06bfea9'), 'name': 'jeeya', 'lname': 'mehra', 'city': 'ludhiana', 'salary': 34000}
# {'_id': ObjectId('663a66d8e179d4b4b06bfea8'), 'name': 'kanika', 'lname': 'kapoor', 'city': 'jaipur', 'salary': 89000}
# {'_id': ObjectId('663a6579e179d4b4b06bfea7'), 'name': 'kartik', 'lname': 'saluja', 'city': 'mumbai', 'salary': 34000}
# {'_id': ObjectId('663a1835895867b3c2a1a646'), 'name': 'mannat', 'lname': 'kaur', 'city': 'kerala'}
# {'_id': ObjectId('663a62b6e179d4b4b06bfea1'), 'name': 'mannat', 'lname': 'kaur', 'city': 'kerala'}
# {'_id': ObjectId('663a6579e179d4b4b06bfea3'), 'name': 'manpreet', 'lname': 'arora', 'city': 'jal', 'salary': 20000}
# ...

# %%
#if we want to see only 3 records ,,use limit
for x in mycol.find().limit(3):
    print(x)
# Out:
# {'_id': ObjectId('663a176a895867b3c2a1a645'), 'name': 'rahul', 'lname': 'sharma', 'city': 'kolkata'}
# {'_id': ObjectId('663a1835895867b3c2a1a646'), 'name': 'mannat', 'lname': 'kaur', 'city': 'kerala'}
# {'_id': ObjectId('663a194f895867b3c2a1a647'), 'name': 'ritvik', 'lname': 'arora', 'city': 'mumbai', 'salary': 130000}

# %%
#update record
oldquery={"name":"swati"}
newquery={"$set":{"name":"shruti"}}

# %%
#updating old record to new one
mycol.update_one(oldquery,newquery)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000002f9'), 'opTime': {'ts': Timestamp(1715105636, 1), 't': 761}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1715105636, 1), 'signature': {'hash': b'\x83\x00\x14\x00\x18J\xf9n\xc47\xcc\xce\xc86\xd1\xc0\xf35\xdei', 'keyId': 7326027773800087553}}, 'operationTime': Timestamp(1715105636, 1), 'updatedExisting': True}, acknowledged=True)

# %%
for x in mycol.find():
    print(x)
# Out:
# {'_id': ObjectId('663a176a895867b3c2a1a645'), 'name': 'rahul', 'lname': 'sharma', 'city': 'kolkata'}
# {'_id': ObjectId('663a1835895867b3c2a1a646'), 'name': 'mannat', 'lname': 'kaur', 'city': 'kerala'}
# {'_id': ObjectId('663a194f895867b3c2a1a647'), 'name': 'ritvik', 'lname': 'arora', 'city': 'mumbai', 'salary': 130000}
# {'_id': ObjectId('663a62b2e179d4b4b06bfea0'), 'name': 'rahul', 'lname': 'sharma', 'city': 'kolkata'}
# {'_id': ObjectId('663a62b6e179d4b4b06bfea1'), 'name': 'mannat', 'lname': 'kaur', 'city': 'kerala'}
# {'_id': ObjectId('663a62bae179d4b4b06bfea2'), 'name': 'ritvik', 'lname': 'arora', 'city': 'mumbai', 'salary': 130000}
# {'_id': ObjectId('663a6579e179d4b4b06bfea3'), 'name': 'manpreet', 'lname': 'arora', 'city': 'jal', 'salary': 20000}
# {'_id': ObjectId('663a6579e179d4b4b06bfea4'), 'name': 'shruti', 'lname': 'kakkar', 'city': 'ludhiana', 'salary': 65000}
# ...

# %%
mycol.update_one({"lname":"kakkar"},{"$set":{'lname':"handa"}})
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000002f9'), 'opTime': {'ts': Timestamp(1715105876, 30), 't': 761}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1715105876, 30), 'signature': {'hash': b'\xd0}\xc1\xed L\x13\xf3\xaf\xe9\x9f\xfc4r\xb6D\x92\tf\xf7', 'keyId': 7326027773800087553}}, 'operationTime': Timestamp(1715105876, 30), 'updatedExisting': True}, acknowledged=True)

# %%
mycol.find_one({"lname":"handa"})
# Out:
# {'_id': ObjectId('663a6579e179d4b4b06bfea4'),
#  'name': 'shruti',
#  'lname': 'handa',
#  'city': 'ludhiana',
#  'salary': 65000}

# %%
#using greater than operation
for x in mycol.find({"salary":{"$gt":35000}}):
    print(x)
# Out:
# {'_id': ObjectId('663a194f895867b3c2a1a647'), 'name': 'ritvik', 'lname': 'arora', 'city': 'mumbai', 'salary': 130000}
# {'_id': ObjectId('663a62bae179d4b4b06bfea2'), 'name': 'ritvik', 'lname': 'arora', 'city': 'mumbai', 'salary': 130000}
# {'_id': ObjectId('663a6579e179d4b4b06bfea4'), 'name': 'shruti', 'lname': 'handa', 'city': 'ludhiana', 'salary': 65000}
# {'_id': ObjectId('663a6579e179d4b4b06bfea6'), 'name': 'abhi', 'lname': 'jain', 'city': 'panipat', 'salary': 140000}
# {'_id': ObjectId('663a66d8e179d4b4b06bfea8'), 'name': 'kanika', 'lname': 'kapoor', 'city': 'jaipur', 'salary': 89000}

# %%
## insert csv file
import pandas as pd
pd.read_csv("C:\\Users\\arora\\downloads\\titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df=pd.read_csv("C:\\Users\\arora\\downloads\\titanic.csv")

# %%
mydb=client["newdata"]

# %%
mycol2=mydb["newdata"]

# %%
df.T.to_json()
# Out:
# '{"0":{"PassengerId":892,"Survived":0,"Pclass":3,"Name":"Kelly, Mr. James","Sex":"male","Age":34.5,"SibSp":0,"Parch":0,"Ticket":"330911","Fare":7.8292,"Cabin":null,"Embarked":"Q"},"1":{"PassengerId":893,"Survived":1,"Pclass":3,"Name":"Wilkes, Mrs. James (Ellen Needs)","Sex":"female","Age":47.0,"SibSp":1,"Parch":0,"Ticket":"363272","Fare":7.0,"Cabin":null,"Embarked":"S"},"2":{"PassengerId":894,"Survived":0,"Pclass":2,"Name":"Myles, Mr. Thomas Francis","Sex":"male","Age":62.0,"SibSp":0,"Parch":0,"Ticket":"240276","Fare":9.6875,"Cabin":null,"Embarked":"Q"},"3":{"PassengerId":895,"Survived":0,"Pclass":3,"Name":"Wirz, Mr. Albert","Sex":"male","Age":27.0,"SibSp":0,"Parch":0,"Ticket":"315154","Fare":8.6625,"Cabin":null,"Embarked":"S"},"4":{"PassengerId":896,"Survived":1,"Pclass":3,"Name":"Hirvonen, Mrs. Alexander (Helga E Lindqvist)","Sex":"female","Age":22.0,"SibSp":1,"Parch":1,"Ticket":"3101298","Fare":12.2875,"Cabin":null,"Embarked":"S"},"5":{"PassengerId":897,"Survived":0,"Pclass":3,"Na
# ...

# %%
import json

# %%
json.loads(df.T.to_json())
# Out:
# {'0': {'PassengerId': 892,
#   'Survived': 0,
#   'Pclass': 3,
#   'Name': 'Kelly, Mr. James',
#   'Sex': 'male',
#   'Age': 34.5,
#   'SibSp': 0,
#   'Parch': 0,
#   'Ticket': '330911',
#   'Fare': 7.8292,
#   'Cabin': None,
#   'Embarked': 'Q'},
#  '1': {'PassengerId': 893,
#   'Survived': 1,
#   'Pclass': 3,
#   'Name': 'Wilkes, Mrs. James (Ellen Needs)',
#   'Sex': 'female',
#   'Age': 47.0,
#   'SibSp': 1,
#   'Parch': 0,
#   'Ticket': '363272',
#   'Fare': 7.0,
#   'Cabin': None,
#   'Embarked': 'S'},
#  '2': {'PassengerId': 894,
#   'Survived': 0,
#   'Pclass': 2,
#   'Name': 'Myles, Mr. Thomas Francis',
#   'Sex': 'male',
#   'Age': 62.0,
#   'SibSp': 0,
#   'Parch': 0,
#   'Ticket': '240276',
#   'Fare': 9.6875,
#   'Cabin': None,
#   'Embarked': 'Q'},
#  '3': {'PassengerId': 895,
#   'Survived': 0,
#   'Pclass': 3,
#   'Name': 'Wirz, Mr. Albert',
#   'Sex': 'male',
#   'Age': 27.0,
#   'SibSp': 0,
#   'Parch': 0,
#   'Ticket': '315154',
#   'Fare': 8.6625,
# ...

# %%
#converting to list
dataset=list(json.loads(df.T.to_json()).values())

# %%
mycol2.insert_many(dataset)
# Out:
# InsertManyResult([ObjectId('663a7e26e179d4b4b06bfeac'), ObjectId('663a7e26e179d4b4b06bfead'), ObjectId('663a7e26e179d4b4b06bfeae'), ObjectId('663a7e26e179d4b4b06bfeaf'), ObjectId('663a7e26e179d4b4b06bfeb0'), ObjectId('663a7e26e179d4b4b06bfeb1'), ObjectId('663a7e26e179d4b4b06bfeb2'), ObjectId('663a7e26e179d4b4b06bfeb3'), ObjectId('663a7e26e179d4b4b06bfeb4'), ObjectId('663a7e26e179d4b4b06bfeb5'), ObjectId('663a7e26e179d4b4b06bfeb6'), ObjectId('663a7e26e179d4b4b06bfeb7'), ObjectId('663a7e26e179d4b4b06bfeb8'), ObjectId('663a7e26e179d4b4b06bfeb9'), ObjectId('663a7e26e179d4b4b06bfeba'), ObjectId('663a7e26e179d4b4b06bfebb'), ObjectId('663a7e26e179d4b4b06bfebc'), ObjectId('663a7e26e179d4b4b06bfebd'), ObjectId('663a7e26e179d4b4b06bfebe'), ObjectId('663a7e26e179d4b4b06bfebf'), ObjectId('663a7e26e179d4b4b06bfec0'), ObjectId('663a7e26e179d4b4b06bfec1'), ObjectId('663a7e26e179d4b4b06bfec2'), ObjectId('663a7e26e179d4b4b06bfec3'), ObjectId('663a7e26e179d4b4b06bfec4'), ObjectId('663a7e26e179d4b4b06b
# ...
